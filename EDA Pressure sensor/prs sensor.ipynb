# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline 
import os 
import warnings 
warnings.filterwarnings('ignore')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\hodei\\EDA Pressure sensor'

# %%
sensor=pd.read_csv('C:\\Users\\hodei\\EDA Pressure sensor\Prs_sensor.csv')
sensor
# Out:
#        station_id     longitude       latitude                  time  \
# 0             NaN  degrees_east  degrees_north                   UTC
# 1              M1         -11.2        53.1266  2001-02-06T13:00:00Z
# 2              M1         -11.2        53.1266  2001-02-06T14:00:00Z
# 3              M1         -11.2        53.1266  2001-02-06T15:00:00Z
# 4              M1         -11.2        53.1266  2001-02-06T16:00:00Z
# ...           ...           ...            ...                   ...
# 613388         M6      -15.8813        53.0748  2017-11-28T09:00:00Z
# 613389         M2      -5.42405         53.481  2017-11-28T10:00:00Z
# 613390         M4      -9.99914             55  2017-11-28T10:00:00Z
# 613391         M5      -6.70434        51.6904  2017-11-28T10:00:00Z
# 613392         M6      -15.8813        53.0748  2017-11-28T10:00:00Z
#
#        AtmosphericPressure WindDirection WindSpeed    Gust WaveHeight  \
# ...

# %%
sensor.head()
# Out:
#   station_id     longitude       latitude                  time  \
# 0        NaN  degrees_east  degrees_north                   UTC
# 1         M1         -11.2        53.1266  2001-02-06T13:00:00Z
# 2         M1         -11.2        53.1266  2001-02-06T14:00:00Z
# 3         M1         -11.2        53.1266  2001-02-06T15:00:00Z
# 4         M1         -11.2        53.1266  2001-02-06T16:00:00Z
#
#   AtmosphericPressure WindDirection WindSpeed  Gust WaveHeight WavePeriod  \
# 0                  mb  degrees_true        kn    kn          m          s
# 1               967.6         270.0     21.98  33.1        NaN        NaN
# 2               969.8         270.0     23.93  35.0        NaN        NaN
# 3               972.0         270.0     19.07  31.1        NaN        NaN
# 4               973.6         270.0     15.95  25.3        NaN        NaN
#
#   MeanWaveDirection Hmax AirTemperature  DewPoint SeaTemperature  \
# 0      degrees_true    m       degree_C  degree_C       degree_C
# ...

# %%
sensor.tail()
# Out:
#        station_id longitude latitude                  time  \
# 613388         M6  -15.8813  53.0748  2017-11-28T09:00:00Z
# 613389         M2  -5.42405   53.481  2017-11-28T10:00:00Z
# 613390         M4  -9.99914       55  2017-11-28T10:00:00Z
# 613391         M5  -6.70434  51.6904  2017-11-28T10:00:00Z
# 613392         M6  -15.8813  53.0748  2017-11-28T10:00:00Z
#
#        AtmosphericPressure WindDirection WindSpeed    Gust WaveHeight  \
# 613388              1026.1           340        18      29        3.4
# 613389             1011.93           NaN    21.916  28.462      1.719
# 613390             1018.99             3    20.493  28.035        NaN
# 613391             1015.44           339    21.631  28.462      1.719
# 613392              1026.5           360        21      27        3.1
#
#        WavePeriod MeanWaveDirection   Hmax AirTemperature DewPoint  \
# 613388          7               NaN    NaN              9      4.2
# ...

# %%
sensor.dtypes
# Out:
# station_id              object
# longitude               object
# latitude                object
# time                    object
# AtmosphericPressure     object
# WindDirection           object
# WindSpeed               object
# Gust                    object
# WaveHeight              object
# WavePeriod              object
# MeanWaveDirection       object
# Hmax                    object
# AirTemperature          object
# DewPoint                object
# SeaTemperature          object
# RelativeHumidity        object
# QC_Flag                float64
# dtype: object

# %%
#Dropping irrelevant columns
sensor= sensor.drop(['WaveHeight', 'WavePeriod', 'MeanWaveDirection', 'Hmax', 'DewPoint', 'RelativeHumidity'], axis=1)

# %%
sensor.head()
# Out:
#   station_id     longitude       latitude                  time  \
# 0        NaN  degrees_east  degrees_north                   UTC
# 1         M1         -11.2        53.1266  2001-02-06T13:00:00Z
# 2         M1         -11.2        53.1266  2001-02-06T14:00:00Z
# 3         M1         -11.2        53.1266  2001-02-06T15:00:00Z
# 4         M1         -11.2        53.1266  2001-02-06T16:00:00Z
#
#   AtmosphericPressure WindDirection WindSpeed  Gust AirTemperature  \
# 0                  mb  degrees_true        kn    kn       degree_C
# 1               967.6         270.0     21.98  33.1            8.9
# 2               969.8         270.0     23.93  35.0            8.5
# 3               972.0         270.0     19.07  31.1            8.9
# 4               973.6         270.0     15.95  25.3            9.1
#
#   SeaTemperature  QC_Flag
# 0       degree_C      NaN
# 1            9.0      1.0
# 2            9.0      1.0
# 3            9.0      1.0
# 4            9.0      1.0

# %%
duplicate_rows_sensor = sensor[sensor.duplicated()]
print("number of duplicate rows:", duplicate_rows_sensor.shape)
# Out:
# number of duplicate rows: (0, 11)

# %%
sensor.count()
# Out:
# station_id             613392
# longitude              613393
# latitude               613393
# time                   613393
# AtmosphericPressure    599242
# WindDirection          588582
# WindSpeed              557220
# Gust                   510294
# AirTemperature         605453
# SeaTemperature         556618
# QC_Flag                613392
# dtype: int64

# %%
#Dropping the missing or null values
print(sensor.isnull().sum())
# Out:
# station_id                  1
# longitude                   0
# latitude                    0
# time                        0
# AtmosphericPressure     14151
# WindDirection           24811
# WindSpeed               56173
# Gust                   103099
# AirTemperature           7940
# SeaTemperature          56775
# QC_Flag                     1
# dtype: int64

# %%
sensor = sensor.dropna() 
sensor.count()
# Out:
# station_id             469444
# longitude              469444
# latitude               469444
# time                   469444
# AtmosphericPressure    469444
# WindDirection          469444
# WindSpeed              469444
# Gust                   469444
# AirTemperature         469444
# SeaTemperature         469444
# QC_Flag                469444
# dtype: int64

# %%
print(sensor.isnull().sum())
# Out:
# station_id             0
# longitude              0
# latitude               0
# time                   0
# AtmosphericPressure    0
# WindDirection          0
# WindSpeed              0
# Gust                   0
# AirTemperature         0
# SeaTemperature         0
# QC_Flag                0
# dtype: int64

# %%
sensor.head()
# Out:
#   station_id longitude latitude                  time AtmosphericPressure  \
# 1         M1     -11.2  53.1266  2001-02-06T13:00:00Z               967.6
# 2         M1     -11.2  53.1266  2001-02-06T14:00:00Z               969.8
# 3         M1     -11.2  53.1266  2001-02-06T15:00:00Z               972.0
# 4         M1     -11.2  53.1266  2001-02-06T16:00:00Z               973.6
# 5         M1     -11.2  53.1266  2001-02-06T18:00:00Z               976.4
#
#   WindDirection WindSpeed  Gust AirTemperature SeaTemperature  QC_Flag
# 1         270.0     21.98  33.1            8.9            9.0      1.0
# 2         270.0     23.93  35.0            8.5            9.0      1.0
# 3         270.0     19.07  31.1            8.9            9.0      1.0
# 4         270.0     15.95  25.3            9.1            9.0      1.0
# 5         270.0     12.06  19.5            8.8            9.0      1.0

# %%
sensor['AtmosphericPressure']=sensor['AtmosphericPressure'].astype('float64')

# %%
sensor.dtypes
# Out:
# station_id              object
# longitude               object
# latitude                object
# time                    object
# AtmosphericPressure    float64
# WindDirection           object
# WindSpeed               object
# Gust                    object
# AirTemperature          object
# SeaTemperature          object
# QC_Flag                float64
# dtype: object

# %%
sensor['station_id']=sensor['station_id'].astype('category')

# %%
sensor['longitude']=sensor['longitude'].astype('float64')

# %%
sensor['latitude']=sensor['latitude'].astype('float64')

# %%
sensor['WindDirection']=sensor['WindDirection'].astype('float64')

# %%
sensor['WindSpeed']=sensor['WindSpeed'].astype('float64')

# %%
sensor['Gust']=sensor['Gust'].astype('float64')

# %%
sensor['AirTemperature']=sensor['AirTemperature'].astype('float64')

# %%
sensor['SeaTemperature']=sensor['SeaTemperature'].astype('float64')

# %%
sensor.dtypes
# Out:
# station_id             category
# longitude               float64
# latitude                float64
# time                     object
# AtmosphericPressure     float64
# WindDirection           float64
# WindSpeed               float64
# Gust                    float64
# AirTemperature          float64
# SeaTemperature          float64
# QC_Flag                 float64
# dtype: object

# %%
#outlayers
sns.boxplot(x=sensor['AtmosphericPressure'])
# Out:
# <AxesSubplot:xlabel='AtmosphericPressure'>

# %%
sensor.WindSpeed.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title('reations between pressure and WindSpeed ')
plt.ylabel('AtmosphericPressure')
plt.xlabel('WindSpeed');

# %%
sensor.AtmosphericPressure.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title('reations between pressure and AirTemperature')
plt.ylabel('AirTemperature')
plt.xlabel('AtmosphericPressure');

# %%
sensor.AtmosphericPressure.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title('reations between pressure Gust')
plt.ylabel('Gust')
plt.xlabel('AtmosphericPressure');

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(sensor['AtmosphericPressure'], sensor['latitude'])
ax.set_xlabel('AtmosphericPressure')
ax.set_ylabel('latitude')
plt.title('reations between pressure and latitude ')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(sensor['AtmosphericPressure'], sensor['longitude'])
ax.set_xlabel('AtmosphericPressure')
ax.set_ylabel('longitude')
plt.title('reations between pressure and longitude ')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(sensor['AtmosphericPressure'], sensor['longitude'])
ax.set_xlabel('AtmosphericPressure')
ax.set_ylabel('longitude')
plt.title('reations between pressure and Time ')

plt.show()

# %%
#relation between variables
plt.figure(figsize=(20,10))
c= sensor.corr()
sns.heatmap(c,cmap='BrBG',annot=True)
c
# Out:
#                      longitude  latitude  AtmosphericPressure  WindDirection  \
# longitude             1.000000 -0.017918             0.048055      -0.054126
# latitude             -0.017918  1.000000            -0.097639      -0.017211
# AtmosphericPressure   0.048055 -0.097639             1.000000      -0.079370
# WindDirection        -0.054126 -0.017211            -0.079370       1.000000
# WindSpeed            -0.096162  0.031819            -0.374549       0.123220
# Gust                 -0.159073  0.033666            -0.396736       0.142187
# AirTemperature       -0.090483 -0.109364             0.050124       0.035286
# SeaTemperature       -0.167919 -0.118751             0.033928       0.057436
# QC_Flag               0.000892 -0.010943            -0.026906       0.000144
#
#                      WindSpeed      Gust  AirTemperature  SeaTemperature  \
# longitude            -0.096162 -0.159073       -0.090483       -0.167919
# ...
